# %% [markdown]
# # Settings to run on Google Colab
# Stores the trained models in Google Drive
#
# Comment the following out if running on your own system

# %%
import os
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
path = 'gdrive/My Drive/Colab Notebooks/Learning-to-See-in-the-Dark/'
os.listdir(path)
# Out:
# ['dataset',
#  'gan_train_Sony_pytorch.ipynb',
#  'datasetLoader_pytorch.py',
#  'models_pytorch.py',
#  'images',
#  'models',
#  'plots',
#  '__pycache__',
#  'train_Sony_pytorch.ipynb',
#  'gan_models.py']

# %%
# Only for Google Colab
import sys
sys.path.insert(0, 'gdrive/My Drive/Colab Notebooks/Learning-to-See-in-the-Dark')

# %% [markdown]
# # Settings to run on your own system¶
# Comment the following out if running on Google Drive

# %%
#path = ''

# %% [markdown]
# # Folder Structure

# %%
import os

def list_files(startpath):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * (level)
        print('{}{}/'.format(indent, os.path.basename(root)))
        subindent = ' ' * 4 * (level + 1)
        for f in files:
            print('{}{}'.format(subindent, f))
            
# currentDirectory = os.getcwd() # For working on own system
currentDirectory = path # For working on Google Colab

list_files(currentDirectory)
# Out:
# /
#     gan_train_Sony_pytorch.ipynb
#     datasetLoader_pytorch.py
#     models_pytorch.py
#     train_Sony_pytorch.ipynb
#     gan_models.py
# dataset/
#     Sony/
#         long_temp_down.zip
#         short_temp_down.zip
#         long_temp_down/
#             00002_10_10s.png
#             00002_8_10s.png
#             00002_9_10s.png
#             00002_7_10s.png
#             00002_6_10s.png
#             00002_5_10s.png
#             00002_4_10s.png
#             00002_1_10s.png
#             00002_2_10s.png
#             00001_11_10s.png
#             00002_3_10s.png
#             00002_0_10s.png
#             00001_10_10s.png
#             00001_9_10s.png
#             00001_8_10s.png
#             00001_1_10s.png
#             00001_0_10s.png
#             00001_4_10s.png
#             00001_6_10s.png
#             00001_3_10s.png
#             00001_7_10s.png
#             00001_2_10s.png
#             00001_5_10s.png
#             00004_6_10s.png
#             00004_9_10s.png
#             00004_7_10s.png
#             00004_8_10s.png
#             00004_5_10s.png
#             00004_4_10s.png
#             00004_3_10s.png
#             00004_2_10s.png
#             00004_1_10s.png
#             00004_0_10s.png
#             00002_11_10s.png
#             .gitkeep
#         short_temp_down/
#             00004_06_0.1s.png
#             00004_05_0.1s.png
#             00004_04_0.1s.png
#             00004_02_0.1s.png
#             00004_03_0.1s.png
#             00004_01_0.1s.png
#             00004_02_0.04s.png
#             00002_07_0.1s.png
#             00004_01_0.04s.png
#             00004_00_0.1s.png
#             00002_08_0.1s.png
#             00004_00_0.04s.png
#             00002_09_0.1s.png
#             00002_04_0.1s.png
#             00002_06_0.1s.png
#             00002_05_0.1s.png
#             00002_03_0.1s.png
#             00002_02_0.1s.png
#             00002_01_0.1s.png
#             00001_08_0.1s.png
#             00001_09_0.1s.png
#             00002_01_0.04s.png
#             00002_00_0.04s.png
#             00002_00_0.1s.png
#             00001_00_0.1s.png
#             00001_03_0.1s.png
#             00001_05_0.1s.png
#             00001_04_0.1s.png
#             00001_06_0.1s.png
#             00001_07_0.1s.png
#             00001_02_0.1s.png
#             00001_01_0.1s.png
#             00001_01_0.04s.png
#             00001_00_0.04s.png
#             .gitkeep
#         short_down/
#             00010_06_0.1s.png
#             00010_05_0.1s.png
#             00010_04_0.1s.png
#             00010_03_0.1s.png
#             00010_07_0.1s.png
#             00010_02_0.1s.png
#             00010_00_0.1s.png
#             00010_01_0.04s.png
#             00010_01_0.1s.png
#             00009_09_0.1s.png
#             00009_08_0.1s.png
#             00009_06_0.1s.png
#             00009_07_0.1s.png
#             00010_00_0.04s.png
#             00009_05_0.1s.png
#             00009_01_0.1s.png
#             00009_03_0.1s.png
#             00009_00_0.1s.png
#             00009_04_0.1s.png
#             00009_01_0.04s.png
#             00009_02_0.1s.png
#             00009_00_0.04s.png
#             00004_09_0.1s.png
#             00004_08_0.1s.png
#             00004_03_0.1s.png
#             00004_02_0.1s.png
#             00004_06_0.1s.png
#             00004_07_0.1s.png
#             00004_04_0.1s.png
#             00004_05_0.1s.png
#             00004_02_0.04s.png
#             00004_01_0.1s.png
#             00004_00_0.1s.png
#             00002_09_0.1s.png
#             00004_00_0.04s.png
#             00002_06_0.1s.png
#             00002_08_0.1s.png
#             00004_01_0.04s.png
#             00002_07_0.1s.png
#             00002_05_0.1s.png
#             00002_03_0.1s.png
#             00002_02_0.1s.png
#             00002_04_0.1s.png
#             00001_09_0.1s.png
#             00002_00_0.04s.png
#             00002_00_0.1s.png
#             00002_01_0.04s.png
#             00002_01_0.1s.png
#             00001_08_0.1s.png
#             00001_07_0.1s.png
#             00001_03_0.1s.png
#             00001_05_0.1s.png
#             00001_04_0.1s.png
#             00001_01_0.1s.png
#             00001_00_0.04s.png
#             00001_06_0.1s.png
#             00001_00_0.1s.png
#             00001_01_0.04s.png
#             00001_02_0.1s.png
#             00010_08_0.1s.png
#             00010_09_0.1s.png
#             00012_00_0.04s.png
#             00012_01_0.04s.png
#             00029_04_0.1s.png
#             00029_02_0.1s.png
#             00029_03_0.1s.png
#             00029_01_0.1s.png
#             00029_00_0.1s.png
#             00029_01_0.04s.png
#             00028_09_0.1s.png
#             00028_08_0.1s.png
#             00029_00_0.04s.png
#             00028_04_0.1s.png
#             00028_06_0.1s.png
#             00028_07_0.1s.png
#             00028_05_0.1s.png
#             00028_03_0.1s.png
#             00028_02_0.1s.png
#             00028_01_0.1s.png
#             00028_01_0.04s.png
#             00028_00_0.1s.png
#             00028_00_0.04s.png
#             00027_07_0.1s.png
#             00027_06_0.1s.png
#             00027_05_0.1s.png
#             00027_09_0.1s.png
#             00027_03_0.1s.png
#             00027_08_0.1s.png
#             00027_00_0.1s.png
#             00027_04_0.1s.png
#             00027_01_0.04s.png
#             00027_00_0.04s.png
#             00027_01_0.1s.png
#             00027_02_0.1s.png
#             00026_09_0.1s.png
#             00026_08_0.1s.png
#             00026_07_0.1s.png
#             00026_06_0.1s.png
#             00026_04_0.1s.png
#             00026_03_0.1s.png
#             00026_02_0.1s.png
#             00026_05_0.1s.png
#             00026_00_0.1s.png
#             00026_01_0.04s.png
#             00024_09_0.1s.png
#             00026_00_0.04s.png
#             00026_01_0.1s.png
#             00024_06_0.1s.png
#             00024_04_0.1s.png
#             00024_05_0.1s.png
#             00024_08_0.1s.png
#             00024_07_0.1s.png
#             00024_01_0.04s.png
#             00024_01_0.1s.png
#             00024_00_0.1s.png
#             00024_03_0.1s.png
#             00024_02_0.1s.png
#             00024_00_0.04s.png
#             00023_07_0.1s.png
#             00023_09_0.1s.png
#             00023_08_0.1s.png
#             00023_04_0.1s.png
#             00023_03_0.1s.png
#             00023_06_0.1s.png
#             00023_05_0.1s.png
#             00023_02_0.1s.png
#             00023_01_0.1s.png
#             00023_00_0.1s.png
#             00023_01_0.04s.png
#             00023_00_0.04s.png
#             00021_07_0.1s.png
#             00021_08_0.1s.png
#             00021_09_0.1s.png
#             00021_06_0.1s.png
#             00021_02_0.1s.png
#             00021_01_0.1s.png
#             00021_05_0.1s.png
#             00021_03_0.1s.png
#             00021_04_0.1s.png
#             00021_01_0.04s.png
#             00021_00_0.1s.png
#             00019_09_0.1s.png
#             00021_00_0.04s.png
#             00019_08_0.1s.png
#             00019_02_0.1s.png
#             00019_03_0.1s.png
#             00019_07_0.1s.png
#             00019_06_0.1s.png
#             00019_05_0.1s.png
#             00019_04_0.1s.png
#             00019_01_0.1s.png
#             00019_01_0.04s.png
#             00019_00_0.1s.png
#             00018_06_0.1s.png
#             00018_08_0.1s.png
#             00018_07_0.1s.png
#             00019_00_0.04s.png
#             00018_09_0.1s.png
#             00018_05_0.1s.png
#             00018_04_0.1s.png
#             00018_03_0.1s.png
#             00018_02_0.1s.png
#             00018_01_0.04s.png
#             00018_01_0.1s.png
#             00018_00_0.1s.png
#             00018_00_0.04s.png
#             00017_09_0.1s.png
#             00017_08_0.1s.png
#             00017_07_0.1s.png
#             00017_06_0.1s.png
#             00017_04_0.1s.png
#             00017_05_0.1s.png
#             00017_02_0.1s.png
#             00017_01_0.1s.png
#             00017_00_0.1s.png
#             00017_03_0.1s.png
#             00017_00_0.04s.png
#             00015_08_0.1s.png
#             00015_07_0.1s.png
#             00017_01_0.04s.png
#             00015_06_0.1s.png
#             00015_04_0.1s.png
#             00015_09_0.1s.png
#             00015_03_0.1s.png
#             00015_01_0.1s.png
#             00015_02_0.1s.png
#             00015_05_0.1s.png
#             00015_01_0.04s.png
#             00015_00_0.1s.png
#             00015_00_0.04s.png
#             00014_09_0.1s.png
#             00014_07_0.1s.png
#             00014_08_0.1s.png
#             00014_06_0.1s.png
#             00014_04_0.1s.png
#             00014_02_0.1s.png
#             00014_05_0.1s.png
#             00014_01_0.1s.png
#             00014_03_0.1s.png
#             00014_00_0.1s.png
#             00014_00_0.04s.png
#             00014_01_0.04s.png
#             00013_09_0.1s.png
#             00013_07_0.1s.png
#             00013_06_0.1s.png
#             00013_08_0.1s.png
#             00013_05_0.1s.png
#             00013_04_0.1s.png
#             00013_03_0.1s.png
#             00013_02_0.1s.png
#             00013_01_0.04s.png
#             00013_00_0.04s.png
#             00013_00_0.1s.png
#             00013_01_0.1s.png
#             00012_09_0.1s.png
#             00012_08_0.1s.png
#             00012_07_0.1s.png
#             00012_06_0.1s.png
#             00012_05_0.1s.png
#             00012_03_0.1s.png
#             00012_02_0.1s.png
#             00012_04_0.1s.png
#             00012_01_0.1s.png
#             00012_00_0.1s.png
#             00042_02_0.1s.png
#             00042_01_0.1s.png
#             00042_01_0.04s.png
#             00042_04_0.1s.png
#             00042_00_0.1s.png
#             00042_03_0.1s.png
#             00041_08_0.1s.png
#             00041_09_0.1s.png
#             00041_07_0.1s.png
#             00041_05_0.1s.png
#             00042_00_0.04s.png
#             00041_04_0.1s.png
#             00041_06_0.1s.png
#             00041_02_0.1s.png
#             00041_01_0.1s.png
#             00041_03_0.1s.png
#             00041_01_0.04s.png
#             00041_00_0.04s.png
#             00041_00_0.1s.png
#             00039_10_0.1s.png
#             00039_09_0.1s.png
#             00039_07_0.1s.png
#             00039_06_0.1s.png
#             00039_08_0.1s.png
#             00039_05_0.1s.png
#             00039_04_0.1s.png
#             00039_03_0.1s.png
#             00039_02_0.1s.png
#             00039_01_0.1s.png
#             00039_00_0.04s.png
#             00038_09_0.1s.png
#             00039_01_0.04s.png
#             00039_00_0.1s.png
#             00038_08_0.1s.png
#             00038_04_0.1s.png
#             00038_07_0.1s.png
#             00038_05_0.1s.png
#             00038_06_0.1s.png
#             00038_03_0.1s.png
#             00038_02_0.1s.png
#             00038_01_0.1s.png
#             00038_01_0.04s.png
#             00038_00_0.1s.png
#             00038_00_0.04s.png
#             00037_07_0.1s.png
#             00037_08_0.1s.png
#             00037_06_0.1s.png
#             00037_09_0.1s.png
#             00037_05_0.1s.png
#             00037_04_0.1s.png
#             00037_03_0.1s.png
#             00037_02_0.1s.png
#             00037_00_0.1s.png
#             00037_01_0.1s.png
#             00036_09_0.1s.png
#             00037_01_0.04s.png
#             00036_08_0.1s.png
#             00036_06_0.1s.png
#             00037_00_0.04s.png
#             00036_04_0.1s.png
#             00036_05_0.1s.png
#             00036_07_0.1s.png
#             00036_02_0.1s.png
#             00036_03_0.1s.png
#             00036_00_0.1s.png
#             00036_01_0.04s.png
#             00033_09_0.1s.png
#             00033_08_0.1s.png
#             00036_01_0.1s.png
#             00033_06_0.1s.png
#             00036_00_0.04s.png
#             00033_03_0.1s.png
#             00033_04_0.1s.png
#             00033_07_0.1s.png
#             00033_02_0.1s.png
#             00033_01_0.1s.png
#             00033_05_0.1s.png
#             00033_01_0.04s.png
#             00033_00_0.1s.png
#             00031_09_0.1s.png
#             00031_05_0.1s.png
#             00033_00_0.04s.png
#             00031_08_0.1s.png
#             00031_07_0.1s.png
#             00031_06_0.1s.png
#             00031_03_0.1s.png
#             00031_04_0.1s.png
#             00031_02_0.1s.png
#             00031_01_0.1s.png
#             00031_01_0.04s.png
#             00031_00_0.04s.png
#             00031_00_0.1s.png
#             00029_08_0.1s.png
#             00029_06_0.1s.png
#             00029_07_0.1s.png
#             00029_05_0.1s.png
#             00029_09_0.1s.png
#             00062_06_0.1s.png
#             00062_00_0.1s.png
#             00062_01_0.04s.png
#             00060_09_0.1s.png
#             00062_03_0.1s.png
#             00062_05_0.1s.png
#             00062_04_0.1s.png
#             00062_02_0.1s.png
#             00062_01_0.1s.png
#             00062_00_0.04s.png
#             00060_08_0.1s.png
#             00060_07_0.1s.png
#             00060_06_0.1s.png
#             00060_01_0.1s.png
#             00060_04_0.1s.png
#             00060_05_0.1s.png
#             00060_01_0.04s.png
#             00060_02_0.1s.png
#             00060_03_0.1s.png
#             00060_00_0.1s.png
#             00060_00_0.04s.png
#             00059_06_0.1s.png
#             00059_09_0.1s.png
#             00059_05_0.1s.png
#             00059_04_0.1s.png
#             00059_07_0.1s.png
#             00059_08_0.1s.png
#             00059_03_0.1s.png
#             00059_02_0.1s.png
#             00059_01_0.1s.png
#             00058_10_0.1s.png
#             00059_00_0.04s.png
#             00059_00_0.1s.png
#             00058_09_0.1s.png
#             00059_01_0.04s.png
#             00058_08_0.1s.png
#             00058_06_0.1s.png
#             00058_07_0.1s.png
#             00058_03_0.1s.png
#             00058_05_0.1s.png
#             00058_04_0.1s.png
#             00058_02_0.1s.png
#             00058_01_0.04s.png
#             00058_01_0.1s.png
#             00058_00_0.1s.png
#             00058_00_0.04s.png
#             00057_09_0.1s.png
#             00057_08_0.1s.png
#             00057_06_0.1s.png
#             00057_07_0.1s.png
#             00057_04_0.1s.png
#             00057_02_0.1s.png
#             00057_05_0.1s.png
#             00057_03_0.1s.png
#             00057_01_0.1s.png
#             00057_00_0.04s.png
#             00057_01_0.04s.png
#             00057_00_0.1s.png
#             00056_08_0.1s.png
#             00056_05_0.1s.png
#             00056_07_0.1s.png
#             00056_09_0.1s.png
#             00056_04_0.1s.png
#             00056_06_0.1s.png
#             00056_03_0.1s.png
#             00056_02_0.1s.png
#             00056_01_0.1s.png
#             00056_01_0.04s.png
#             00053_08_0.1s.png
#             00056_00_0.1s.png
#             00056_00_0.04s.png
#             00053_07_0.1s.png
#             00053_05_0.1s.png
#             00053_09_0.1s.png
#             00053_03_0.1s.png
#             00053_04_0.1s.png
#             00053_06_0.1s.png
#             00053_02_0.1s.png
#             00053_01_0.04s.png
#             00053_00_0.1s.png
#             00053_01_0.1s.png
#             00053_00_0.04s.png
#             00052_09_0.1s.png
#             00052_08_0.1s.png
#             00052_07_0.1s.png
#             00052_06_0.1s.png
#             00052_01_0.1s.png
#             00052_02_0.1s.png
#             00052_04_0.1s.png
#             00052_03_0.1s.png
#             00052_05_0.1s.png
#             00052_00_0.1s.png
#             00052_01_0.04s.png
#             00051_07_0.1s.png
#             00051_08_0.1s.png
#             00052_00_0.04s.png
#             00051_06_0.1s.png
#             00051_09_0.1s.png
#             00051_05_0.1s.png
#             00051_04_0.1s.png
#             00051_00_0.04s.png
#             00051_01_0.1s.png
#             00051_02_0.1s.png
#             00051_03_0.1s.png
#             00051_00_0.1s.png
#             00051_01_0.04s.png
#             00050_11_0.1s.png
#             00050_10_0.1s.png
#             00050_09_0.1s.png
#             00050_08_0.1s.png
#             00050_03_0.1s.png
#             00050_04_0.1s.png
#             00050_07_0.1s.png
#             00050_05_0.1s.png
#             00050_02_0.1s.png
#             00050_06_0.1s.png
#             00050_00_0.1s.png
#             00050_01_0.1s.png
#             00050_01_0.04s.png
#             00049_09_0.1s.png
#             00049_07_0.1s.png
#             00049_08_0.1s.png
#             00049_05_0.1s.png
#             00050_00_0.04s.png
#             00049_06_0.1s.png
#             00049_04_0.1s.png
#             00049_03_0.1s.png
#             00049_02_0.1s.png
#             00049_01_0.1s.png
#             00049_00_0.1s.png
#             00049_01_0.04s.png
#             00049_00_0.04s.png
#             00048_07_0.1s.png
#             00048_09_0.1s.png
#             00048_08_0.1s.png
#             00048_06_0.1s.png
#             00048_02_0.1s.png
#             00048_01_0.1s.png
#             00048_05_0.1s.png
#             00048_04_0.1s.png
#             00048_03_0.1s.png
#             00048_00_0.1s.png
#             00048_01_0.04s.png
#             00048_00_0.04s.png
#             00047_09_0.1s.png
#             00047_08_0.1s.png
#             00047_06_0.1s.png
#             00047_04_0.1s.png
#             00047_07_0.1s.png
#             00047_05_0.1s.png
#             00047_03_0.1s.png
#             00047_02_0.1s.png
#             00047_01_0.1s.png
#             00047_01_0.04s.png
#             00047_00_0.1s.png
#             00046_09_0.1s.png
#             00046_07_0.1s.png
#             00047_00_0.04s.png
#             00046_08_0.1s.png
#             00046_05_0.1s.png
#             00046_03_0.1s.png
#             00046_06_0.1s.png
#             00046_01_0.1s.png
#             00046_01_0.04s.png
#             00046_04_0.1s.png
#             00046_00_0.04s.png
#             00046_02_0.1s.png
#             00046_00_0.1s.png
#             00044_08_0.1s.png
#             00044_04_0.1s.png
#             00044_05_0.1s.png
#             00044_03_0.1s.png
#             00044_09_0.1s.png
#             00044_06_0.1s.png
#             00044_07_0.1s.png
#             00044_01_0.04s.png
#             00044_02_0.1s.png
#             00044_00_0.1s.png
#             00044_01_0.1s.png
#             00043_07_0.1s.png
#             00043_11_0.1s.png
#             00044_00_0.04s.png
#             00043_10_0.1s.png
#             00043_08_0.1s.png
#             00043_09_0.1s.png
#             00043_06_0.1s.png
#             00043_05_0.1s.png
#             00043_04_0.1s.png
#             00043_03_0.1s.png
#             00043_01_0.1s.png
#             00043_00_0.04s.png
#             00043_01_0.04s.png
#             00043_02_0.1s.png
#             00043_00_0.1s.png
#             00042_06_0.1s.png
#             00042_07_0.1s.png
#             00042_05_0.1s.png
#             00042_09_0.1s.png
#             00042_08_0.1s.png
#             00086_02_0.1s.png
#             00086_04_0.1s.png
#             00086_05_0.1s.png
#             00086_03_0.1s.png
#             00085_07_0.1s.png
#             00086_00_0.1s.png
#             00085_09_0.1s.png
#             00085_08_0.1s.png
#             00086_01_0.1s.png
#             00085_06_0.1s.png
#             00085_05_0.1s.png
#             00085_04_0.1s.png
#             00085_01_0.1s.png
#             00085_02_0.1s.png
#             00085_03_0.1s.png
#             00085_00_0.1s.png
#             00084_07_0.1s.png
#             00084_09_0.1s.png
#             00084_08_0.1s.png
#             00084_05_0.1s.png
#             00084_04_0.1s.png
#             00084_06_0.1s.png
#             00084_03_0.1s.png
#             00084_00_0.1s.png
#             00084_01_0.1s.png
#             00084_02_0.1s.png
#             00083_08_0.1s.png
#             00083_09_0.1s.png
#             00083_07_0.1s.png
#             00083_06_0.1s.png
#             00083_04_0.1s.png
#             00083_05_0.1s.png
#             00083_03_0.1s.png
#             00083_00_0.1s.png
#             00083_01_0.1s.png
#             00083_02_0.1s.png
#             00081_08_0.1s.png
#             00081_09_0.1s.png
#             00081_07_0.1s.png
#             00081_06_0.1s.png
#             00081_05_0.1s.png
#             00081_04_0.1s.png
#             00081_03_0.1s.png
#             00081_01_0.1s.png
#             00081_02_0.1s.png
#             00081_00_0.1s.png
#             00078_09_0.1s.png
#             00078_08_0.1s.png
#             00078_04_0.1s.png
#             00078_07_0.1s.png
#             00078_06_0.1s.png
#             00078_00_0.1s.png
#             00078_03_0.1s.png
#             00078_05_0.1s.png
#             00078_01_0.1s.png
#             00078_02_0.1s.png
#             00076_06_0.1s.png
#             00076_05_0.1s.png
#             00076_09_0.1s.png
#             00076_08_0.1s.png
#             00076_07_0.1s.png
#             00076_01_0.1s.png
#             00076_04_0.1s.png
#             00076_03_0.1s.png
#             00076_02_0.1s.png
#             00076_00_0.1s.png
#             00075_09_0.1s.png
#             00075_06_0.1s.png
#             00075_07_0.1s.png
#             00075_08_0.1s.png
#             00075_03_0.1s.png
#             00075_05_0.1s.png
#             00075_04_0.1s.png
#             00075_01_0.1s.png
#             00075_02_0.1s.png
#             00073_08_0.1s.png
#             00073_09_0.1s.png
#             00075_00_0.1s.png
#             00073_06_0.1s.png
#             00073_07_0.1s.png
#             00073_05_0.1s.png
#             00073_04_0.1s.png
#             00073_03_0.1s.png
#             00073_01_0.1s.png
#             00073_02_0.1s.png
#             00073_00_0.1s.png
#             00072_08_0.1s.png
#             00072_09_0.1s.png
#             00072_07_0.1s.png
#             00072_06_0.1s.png
#             00072_05_0.1s.png
#             00072_01_0.1s.png
#             00072_04_0.1s.png
#             00072_03_0.1s.png
#             00072_02_0.1s.png
#             00072_00_0.1s.png
#             00071_09_0.1s.png
#             00071_08_0.1s.png
#             00071_04_0.1s.png
#             00070_08_0.1s.png
#             00071_06_0.1s.png
#             00071_07_0.1s.png
#             00071_05_0.1s.png
#             00071_02_0.1s.png
#             00071_01_0.1s.png
#             00071_03_0.1s.png
#             00070_00_0.04s.png
#             00067_08_0.1s.png
#             00070_00_0.1s.png
#             00067_09_0.1s.png
#             00070_02_0.1s.png
#             00070_01_0.1s.png
#             00070_04_0.1s.png
#             00070_03_0.1s.png
#             00070_06_0.1s.png
#             00070_05_0.1s.png
#             00070_07_0.1s.png
#             00071_00_0.04s.png
#             00071_01_0.04s.png
#             00071_00_0.1s.png
#             00070_09_0.1s.png
#             00067_07_0.1s.png
#             00070_01_0.04s.png
#             00067_05_0.1s.png
#             00067_03_0.1s.png
#             00067_04_0.1s.png
#             00067_02_0.1s.png
#             00067_06_0.1s.png
#             00067_01_0.04s.png
#             00067_00_0.04s.png
#             00067_00_0.1s.png
#             00066_09_0.1s.png
#             00067_01_0.1s.png
#             00066_08_0.1s.png
#             00066_04_0.1s.png
#             00066_05_0.1s.png
#             00066_07_0.1s.png
#             00066_06_0.1s.png
#             00066_03_0.1s.png
#             00066_01_0.04s.png
#             00066_02_0.1s.png
#             00066_01_0.1s.png
#             00066_00_0.1s.png
#             00065_09_0.1s.png
#             00065_08_0.1s.png
#             00066_00_0.04s.png
#             00065_06_0.1s.png
#             00065_04_0.1s.png
#             00065_07_0.1s.png
#             00065_03_0.1s.png
#             00065_05_0.1s.png
#             00065_02_0.1s.png
#             00065_01_0.04s.png
#             00065_00_0.1s.png
#             00065_00_0.04s.png
#             00065_01_0.1s.png
#             00064_04_0.1s.png
#             00064_07_0.1s.png
#             00064_09_0.1s.png
#             00064_08_0.1s.png
#             00064_05_0.1s.png
#             00064_06_0.1s.png
#             00064_03_0.1s.png
#             00064_02_0.1s.png
#             00064_01_0.1s.png
#             00064_01_0.04s.png
#             00064_00_0.1s.png
#             00063_09_0.1s.png
#             00064_00_0.04s.png
#             00063_08_0.1s.png
#             00063_03_0.1s.png
#             00063_07_0.1s.png
#             00063_04_0.1s.png
#             00063_06_0.1s.png
#             00063_01_0.1s.png
#             00063_02_0.1s.png
#             00063_05_0.1s.png
#             00063_01_0.04s.png
#             00063_00_0.1s.png
#             00063_00_0.04s.png
#             00062_09_0.1s.png
#             00062_08_0.1s.png
#             00062_07_0.1s.png
#             00114_02_0.1s.png
#             00114_04_0.1s.png
#             00113_06_0.1s.png
#             00113_09_0.1s.png
#             00114_01_0.1s.png
#             00114_00_0.1s.png
#             00113_08_0.1s.png
#             00113_07_0.1s.png
#             00113_02_0.1s.png
#             00113_03_0.1s.png
#             00113_00_0.1s.png
#             00113_05_0.1s.png
#             00113_04_0.1s.png
#             00112_07_0.1s.png
#             00113_01_0.1s.png
#             00112_09_0.1s.png
#             00112_03_0.1s.png
#             00112_08_0.1s.png
#             00112_06_0.1s.png
#             00112_04_0.1s.png
#             00112_05_0.1s.png
#             00112_02_0.1s.png
#             00112_01_0.1s.png
#             00110_09_0.1s.png
#             00110_08_0.1s.png
#             00112_00_0.1s.png
#             00110_04_0.1s.png
#             00110_06_0.1s.png
#             00110_05_0.1s.png
#             00110_07_0.1s.png
#             00110_00_0.1s.png
#             00110_02_0.1s.png
#             00109_08_0.1s.png
#             00110_03_0.1s.png
#             00109_06_0.1s.png
#             00110_01_0.1s.png
#             00109_04_0.1s.png
#             00109_09_0.1s.png
#             00109_07_0.1s.png
#             00109_01_0.1s.png
#             00109_05_0.1s.png
#             00109_03_0.1s.png
#             00108_08_0.1s.png
#             00109_02_0.1s.png
#             00108_07_0.1s.png
#             00108_06_0.1s.png
#             00109_00_0.1s.png
#             00108_05_0.1s.png
#             00108_04_0.1s.png
#             00108_03_0.1s.png
#             00108_01_0.1s.png
#             00108_00_0.1s.png
#             00108_02_0.1s.png
#             00104_08_0.1s.png
#             00104_06_0.1s.png
#             00104_05_0.1s.png
#             00104_07_0.1s.png
#             00102_07_0.1s.png
#             00104_04_0.1s.png
#             00104_03_0.1s.png
#             00104_02_0.1s.png
#             00104_01_0.1s.png
#             00104_00_0.1s.png
#             00102_05_0.1s.png
#             00102_09_0.1s.png
#             00102_08_0.1s.png
#             00102_06_0.1s.png
#             00102_04_0.1s.png
#             00102_03_0.1s.png
#             00102_02_0.1s.png
#             00102_00_0.1s.png
#             00102_01_0.1s.png
#             00100_08_0.1s.png
#             00100_06_0.1s.png
#             00100_09_0.1s.png
#             00100_07_0.1s.png
#             00100_05_0.1s.png
#             00100_04_0.1s.png
#             00100_00_0.1s.png
#             00100_01_0.1s.png
#             00100_03_0.1s.png
#             00100_02_0.1s.png
#             00099_08_0.1s.png
#             00099_09_0.1s.png
#             00099_06_0.1s.png
#             00099_07_0.1s.png
#             00099_04_0.1s.png
#             00099_05_0.1s.png
#             00099_01_0.1s.png
#             00099_00_0.1s.png
#             00099_03_0.1s.png
#             00099_02_0.1s.png
#             00098_05_0.1s.png
#             00098_08_0.1s.png
#             00098_04_0.1s.png
#             00098_06_0.1s.png
#             00098_07_0.1s.png
#             00098_09_0.1s.png
#             00098_03_0.1s.png
#             00098_02_0.1s.png
#             00098_01_0.1s.png
#             00097_09_0.1s.png
#             00097_07_0.1s.png
#             00097_06_0.1s.png
#             00097_08_0.1s.png
#             00098_00_0.1s.png
#             00097_05_0.1s.png
#             00097_04_0.1s.png
#             00097_03_0.1s.png
#             00096_09_0.1s.png
#             00097_00_0.1s.png
#             00097_02_0.1s.png
#             00097_01_0.1s.png
#             00096_08_0.1s.png
#             00096_06_0.1s.png
#             00096_05_0.1s.png
#             00096_07_0.1s.png
#             00096_04_0.1s.png
#             00096_03_0.1s.png
#             00096_01_0.1s.png
#             00096_02_0.1s.png
#             00096_00_0.1s.png
#             00095_09_0.1s.png
#             00095_07_0.1s.png
#             00095_08_0.1s.png
#             00095_05_0.1s.png
#             00095_06_0.1s.png
#             00095_03_0.1s.png
#             00095_04_0.1s.png
#             00094_09_0.1s.png
#             00095_02_0.1s.png
#             00094_07_0.1s.png
#             00095_00_0.1s.png
#             00095_01_0.1s.png
#             00094_08_0.1s.png
#             00094_06_0.1s.png
#             00094_05_0.1s.png
#             00094_04_0.1s.png
#             00094_01_0.1s.png
#             00094_00_0.1s.png
#             00094_03_0.1s.png
#             00094_02_0.1s.png
#             00092_09_0.1s.png
#             00092_03_0.1s.png
#             00092_02_0.1s.png
#             00092_08_0.1s.png
#             00092_04_0.1s.png
#             00092_05_0.1s.png
#             00092_06_0.1s.png
#             00092_07_0.1s.png
#             00092_01_0.1s.png
#             00092_00_0.1s.png
#             00091_08_0.1s.png
#             00091_09_0.1s.png
#             00091_05_0.1s.png
#             00091_04_0.1s.png
#             00091_03_0.1s.png
#             00091_07_0.1s.png
#             00091_06_0.1s.png
#             00091_02_0.1s.png
#             00091_01_0.1s.png
#             00090_09_0.1s.png
#             00091_00_0.1s.png
#             00090_07_0.1s.png
#             00090_06_0.1s.png
#             00090_08_0.1s.png
#             00090_05_0.1s.png
#             00090_02_0.1s.png
#             00090_01_0.1s.png
#             00090_04_0.1s.png
#             00090_03_0.1s.png
#             00090_00_0.1s.png
#             00088_09_0.1s.png
#             00088_08_0.1s.png
#             00088_05_0.1s.png
#             00088_07_0.1s.png
#             00088_06_0.1s.png
#             00088_02_0.1s.png
#             00088_01_0.1s.png
#             00088_04_0.1s.png
#             00088_03_0.1s.png
#             00088_00_0.1s.png
#             00086_09_0.1s.png
#             00086_07_0.1s.png
#             00086_08_0.1s.png
#             00086_06_0.1s.png
#             00132_08_0.1s.png
#             00131_07_0.1s.png
#             00132_01_0.1s.png
#             00131_09_0.1s.png
#             00130_08_0.1s.png
#             00129_09_0.1s.png
#             00129_08_0.1s.png
#             00129_06_0.1s.png
#             00129_03_0.1s.png
#             00129_01_0.1s.png
#             00129_00_0.1s.png
#             00128_09_0.1s.png
#             00128_07_0.1s.png
#             00128_08_0.1s.png
#             00128_05_0.1s.png
#             00128_06_0.1s.png
#             00128_04_0.1s.png
#             00128_02_0.1s.png
#             00128_01_0.1s.png
#             00128_00_0.1s.png
#             00128_03_0.1s.png
#             00127_08_0.1s.png
#             00127_09_0.1s.png
#             00127_07_0.1s.png
#             00127_06_0.1s.png
#             00127_05_0.1s.png
#             00127_03_0.1s.png
#             00127_04_0.1s.png
#             00127_01_0.1s.png
#             00124_09_0.1s.png
#             00124_07_0.1s.png
#             00124_08_0.1s.png
#             00127_02_0.1s.png
#             00127_00_0.1s.png
#             00124_05_0.1s.png
#             00124_06_0.1s.png
#             00124_04_0.1s.png
#             00124_03_0.1s.png
#             00124_01_0.1s.png
#             00124_02_0.1s.png
#             00123_08_0.1s.png
#             00123_06_0.1s.png
#             00123_05_0.1s.png
#             00124_00_0.1s.png
#             00123_09_0.1s.png
#             00123_02_0.1s.png
#             00123_07_0.1s.png
#             00123_04_0.1s.png
#             00122_09_0.1s.png
#             00123_03_0.1s.png
#             00123_00_0.1s.png
#             00123_01_0.1s.png
#             00122_08_0.1s.png
#             00122_00_0.1s.png
#             00122_05_0.1s.png
#             00122_07_0.1s.png
#             00122_06_0.1s.png
#             00122_03_0.1s.png
#             00122_04_0.1s.png
#             00122_02_0.1s.png
#             00122_01_0.1s.png
#             00121_09_0.1s.png
#             00121_07_0.1s.png
#             00121_05_0.1s.png
#             00121_03_0.1s.png
#             00121_04_0.1s.png
#             00121_01_0.1s.png
#             00119_03_0.1s.png
#             00159_05_0.1s.png
#             00159_08_0.1s.png
#             00159_00_0.1s.png
#             00158_08_0.1s.png
#             00158_06_0.1s.png
#             00158_03_0.1s.png
#             00158_02_0.1s.png
#             00158_01_0.1s.png
#             00158_00_0.1s.png
#             00157_09_0.1s.png
#             00157_05_0.1s.png
#             00157_04_0.1s.png
#             00157_06_0.1s.png
#             00157_07_0.1s.png
#             00157_01_0.1s.png
#             00156_09_0.1s.png
#             00157_08_0.1s.png
#             00157_00_0.1s.png
#             00157_03_0.1s.png
#             00156_06_0.1s.png
#             00157_02_0.1s.png
#             00156_04_0.1s.png
#             00156_05_0.1s.png
#             00156_07_0.1s.png
#             00156_08_0.1s.png
#             00156_03_0.1s.png
#             00156_00_0.1s.png
#             00155_08_0.1s.png
#             00151_02_0.1s.png
#             00150_08_0.1s.png
#             00150_09_0.1s.png
#             00151_01_0.1s.png
#             00150_03_0.1s.png
#             00150_07_0.1s.png
#             00150_05_0.1s.png
#             00150_06_0.1s.png
#             00150_04_0.1s.png
#             00150_00_0.1s.png
#             00150_01_0.1s.png
#             00150_02_0.1s.png
#             00149_09_0.1s.png
#             00149_08_0.1s.png
#             00149_04_0.1s.png
#             00149_06_0.1s.png
#             00149_07_0.1s.png
#             00149_05_0.1s.png
#             00149_01_0.1s.png
#             00149_02_0.1s.png
#             00148_02_0.1s.png
#             00148_04_0.1s.png
#             00148_06_0.1s.png
#             00148_07_0.1s.png
#             00148_03_0.1s.png
#             00148_01_0.1s.png
#             00148_00_0.1s.png
#             00146_05_0.1s.png
#             00146_07_0.1s.png
#             00146_04_0.1s.png
#             00146_02_0.1s.png
#             00146_00_0.1s.png
#             00145_06_0.1s.png
#             00145_02_0.1s.png
#             00145_05_0.1s.png
#             00144_09_0.1s.png
#             00145_04_0.1s.png
#             00144_07_0.1s.png
#             00144_06_0.1s.png
#             00144_08_0.1s.png
#             00145_00_0.1s.png
#             00144_05_0.1s.png
#             00144_04_0.1s.png
#             00144_03_0.1s.png
#             00144_02_0.1s.png
#             00144_01_0.1s.png
#             00144_00_0.1s.png
#             00143_08_0.1s.png
#             00143_07_0.1s.png
#             00143_06_0.1s.png
#             00143_05_0.1s.png
#             00143_09_0.1s.png
#             00143_01_0.1s.png
#             00142_09_0.1s.png
#             00143_04_0.1s.png
#             00143_03_0.1s.png
#             00143_02_0.1s.png
#             00143_00_0.1s.png
#             00138_00_0.1s.png
#             00136_06_0.1s.png
#             00136_07_0.1s.png
#             00136_05_0.1s.png
#             00136_04_0.1s.png
#             00136_03_0.1s.png
#             00136_01_0.1s.png
#             00136_02_0.1s.png
#             00136_00_0.1s.png
#             00135_08_0.1s.png
#             00135_07_0.1s.png
#             00135_09_0.1s.png
#             00135_06_0.1s.png
#             00135_05_0.1s.png
#             00135_02_0.1s.png
#             00135_03_0.1s.png
#             00135_04_0.1s.png
#             00134_04_0.1s.png
#             00134_07_0.1s.png
#             00134_08_0.1s.png
#             00134_09_0.1s.png
#             00135_00_0.1s.png
#             00135_01_0.1s.png
#             00134_06_0.1s.png
#             00134_05_0.1s.png
#             00134_03_0.1s.png
#             00134_01_0.1s.png
#             00134_02_0.1s.png
#             00133_05_0.1s.png
#             00134_00_0.1s.png
#             00133_07_0.1s.png
#             00133_09_0.1s.png
#             00133_08_0.1s.png
#             00133_06_0.1s.png
#             00133_04_0.1s.png
#             00133_03_0.1s.png
#             00133_02_0.1s.png
#             00189_01_0.1s.png
#             00189_01_0.04s.png
#             00189_00_0.033s.png
#             00186_08_0.04s.png
#             00189_00_0.1s.png
#             00186_09_0.04s.png
#             00186_05_0.04s.png
#             00186_06_0.04s.png
#             00186_02_0.04s.png
#             00186_01_0.1s.png
#             00186_00_0.04s.png
#             00186_03_0.04s.png
#             00186_01_0.04s.png
#             00186_04_0.04s.png
#             00186_01_0.033s.png
#             00186_00_0.1s.png
#             00186_00_0.033s.png
#             00184_09_0.04s.png
#             00184_07_0.04s.png
#             00184_02_0.04s.png
#             00184_04_0.04s.png
#             00184_06_0.04s.png
#             00184_05_0.04s.png
#             00184_08_0.04s.png
#             00184_03_0.04s.png
#             00184_01_0.1s.png
#             00184_01_0.04s.png
#             00184_00_0.04s.png
#             00184_00_0.033s.png
#             00183_10_0.04s.png
#             00184_01_0.033s.png
#             00184_00_0.1s.png
#             00183_11_0.04s.png
#             00183_09_0.04s.png
#             00183_06_0.04s.png
#             00183_04_0.04s.png
#             00183_00_0.04s.png
#             00182_01_0.1s.png
#             00180_04_0.04s.png
#             00180_09_0.04s.png
#             00181_00_0.033s.png
#             00180_08_0.04s.png
#             00181_00_0.04s.png
#             00180_05_0.04s.png
#             00180_07_0.04s.png
#             00180_06_0.04s.png
#             00180_01_0.1s.png
#             00179_08_0.04s.png
#             00180_00_0.1s.png
#             00179_09_0.04s.png
#             00180_01_0.04s.png
#             00180_00_0.04s.png
#             00180_02_0.04s.png
#             00180_03_0.04s.png
#             00179_03_0.04s.png
#             00179_02_0.1s.png
#             00179_02_0.04s.png
#             00179_05_0.04s.png
#             00179_03_0.1s.png
#             00179_04_0.04s.png
#             00179_07_0.04s.png
#             00179_06_0.04s.png
#             00179_01_0.1s.png
#             00175_05_0.1s.png
#             00175_09_0.1s.png
#             00179_00_0.04s.png
#             00179_00_0.033s.png
#             00179_00_0.1s.png
#             00179_01_0.033s.png
#             00179_01_0.04s.png
#             00175_08_0.1s.png
#             00175_06_0.1s.png
#             00175_04_0.1s.png
#             00175_02_0.1s.png
#             00175_07_0.1s.png
#             00175_01_0.1s.png
#             00175_03_0.1s.png
#             00175_00_0.1s.png
#             00174_02_0.1s.png
#             00174_09_0.1s.png
#             00174_05_0.1s.png
#             00174_07_0.1s.png
#             00174_06_0.1s.png
#             00174_04_0.1s.png
#             00174_08_0.1s.png
#             00174_03_0.1s.png
#             00174_01_0.1s.png
#             00173_04_0.1s.png
#             00173_06_0.1s.png
#             00173_07_0.1s.png
#             00173_08_0.1s.png
#             00173_09_0.1s.png
#             00174_00_0.1s.png
#             00173_05_0.1s.png
#             00173_03_0.1s.png
#             00173_02_0.1s.png
#             00173_01_0.1s.png
#             00171_08_0.1s.png
#             00171_09_0.1s.png
#             00171_07_0.1s.png
#             00171_06_0.1s.png
#             00171_05_0.1s.png
#             00171_04_0.1s.png
#             00169_08_0.1s.png
#             00168_09_0.1s.png
#             00169_01_0.1s.png
#             00168_05_0.1s.png
#             00168_03_0.1s.png
#             00166_03_0.1s.png
#             00165_06_0.1s.png
#             00165_05_0.1s.png
#             00165_09_0.1s.png
#             00165_04_0.1s.png
#             00165_03_0.1s.png
#             00165_01_0.1s.png
#             00164_07_0.1s.png
#             00164_09_0.1s.png
#             00165_00_0.1s.png
#             00165_02_0.1s.png
#             00164_08_0.1s.png
#             00164_04_0.1s.png
#             00164_06_0.1s.png
#             00164_05_0.1s.png
#             00164_00_0.1s.png
#             00164_03_0.1s.png
#             00161_09_0.1s.png
#             00164_02_0.1s.png
#             00161_06_0.1s.png
#             00164_01_0.1s.png
#             00161_05_0.1s.png
#             00161_08_0.1s.png
#             00161_07_0.1s.png
#             00161_04_0.1s.png
#             00161_02_0.1s.png
#             00160_09_0.1s.png
#             00160_07_0.1s.png
#             00160_05_0.1s.png
#             00159_07_0.1s.png
#             00160_00_0.1s.png
#             00220_01_0.033s.png
#             00220_00_0.033s.png
#             00220_00_0.04s.png
#             00219_08_0.04s.png
#             00219_06_0.04s.png
#             00219_07_0.04s.png
#             00219_02_0.04s.png
#             00219_04_0.04s.png
#             00219_01_0.033s.png
#             00219_00_0.1s.png
#             00219_01_0.04s.png
#             00219_00_0.033s.png
#             00219_00_0.04s.png
#             00219_01_0.1s.png
#             00218_09_0.04s.png
#             00218_04_0.04s.png
#             00218_07_0.04s.png
#             00218_06_0.04s.png
#             00218_03_0.04s.png
#             00218_00_0.033s.png
#             00216_08_0.04s.png
#             00218_00_0.04s.png
#             00218_00_0.1s.png
#             00218_01_0.033s.png
#             00218_02_0.04s.png
#             00216_09_0.04s.png
#             00216_03_0.04s.png
#             00216_07_0.04s.png
#             00216_06_0.04s.png
#             00216_04_0.04s.png
#             00216_05_0.04s.png
#             00216_02_0.04s.png
#             00216_01_0.04s.png
#             00216_01_0.1s.png
#             00216_00_0.033s.png
#             00215_09_0.04s.png
#             00216_01_0.033s.png
#             00216_00_0.1s.png
#             00216_00_0.04s.png
#             00215_08_0.04s.png
#             00215_07_0.04s.png
#             00215_06_0.04s.png
#             00215_01_0.04s.png
#             00215_01_0.1s.png
#             00215_02_0.04s.png
#             00215_04_0.04s.png
#             00215_05_0.04s.png
#             00215_03_0.04s.png
#             00215_00_0.04s.png
#             00214_07_0.04s.png
#             00215_00_0.1s.png
#             00214_09_0.04s.png
#             00214_08_0.04s.png
#             00214_02_0.04s.png
#             00212_02_0.04s.png
#             00209_07_0.04s.png
#             00209_02_0.04s.png
#             00209_00_0.04s.png
#             00207_07_0.04s.png
#             00207_06_0.04s.png
#             00207_08_0.04s.png
#             00207_09_0.04s.png
#             00209_00_0.033s.png
#             00207_05_0.04s.png
#             00207_04_0.04s.png
#             00207_02_0.04s.png
#             00207_01_0.1s.png
#             00207_03_0.04s.png
#             00207_02_0.033s.png
#             00207_01_0.04s.png
#             00207_00_0.04s.png
#             00207_01_0.033s.png
#             00207_00_0.1s.png
#             00206_09_0.04s.png
#             00207_00_0.033s.png
#             00206_08_0.04s.png
#             00206_07_0.04s.png
#             00206_06_0.04s.png
#             00206_05_0.04s.png
#             00206_04_0.04s.png
#             00206_03_0.04s.png
#             00206_01_0.1s.png
#             00206_02_0.04s.png
#             00206_00_0.033s.png
#             00206_00_0.04s.png
#             00205_09_0.04s.png
#             00205_07_0.04s.png
#             00205_06_0.04s.png
#             00200_08_0.04s.png
#             00200_06_0.04s.png
#             00200_09_0.04s.png
#             00200_01_0.04s.png
#             00200_04_0.04s.png
#             00200_05_0.04s.png
#             00200_07_0.04s.png
#             00200_01_0.1s.png
#             00200_02_0.04s.png
#             00200_03_0.04s.png
#             00200_00_0.1s.png
#             00200_01_0.033s.png
#             00200_00_0.04s.png
#             00200_00_0.033s.png
#             00197_08_0.04s.png
#             00197_09_0.04s.png
#             00197_07_0.04s.png
#             00197_03_0.04s.png
#             00197_05_0.04s.png
#             00197_06_0.04s.png
#             00197_02_0.04s.png
#             00197_04_0.04s.png
#             00197_01_0.1s.png
#             00197_01_0.04s.png
#             00197_01_0.033s.png
#             00197_00_0.1s.png
#             00197_00_0.04s.png
#             00197_00_0.033s.png
#             00196_09_0.04s.png
#             00196_06_0.04s.png
#             00196_07_0.04s.png
#             00196_08_0.04s.png
#             00196_05_0.04s.png
#             00196_04_0.04s.png
#             00196_03_0.04s.png
#             00196_00_0.1s.png
#             00196_01_0.04s.png
#             00196_02_0.04s.png
#             00196_01_0.1s.png
#             00196_01_0.033s.png
#             00196_00_0.04s.png
#             00195_09_0.1s.png
#             00196_00_0.033s.png
#             00195_07_0.04s.png
#             00195_07_0.1s.png
#             00195_08_0.04s.png
#             00195_09_0.04s.png
#             00195_08_0.1s.png
#             00195_05_0.1s.png
#             00195_06_0.1s.png
#             00195_06_0.04s.png
#             00195_04_0.1s.png
#             00195_03_0.04s.png
#             00195_04_0.04s.png
#             00195_05_0.04s.png
#             00195_03_0.1s.png
#             00195_02_0.1s.png
#             00195_01_0.1s.png
#             00195_02_0.04s.png
#             00195_00_0.1s.png
#             00195_01_0.04s.png
#             00195_00_0.04s.png
#             00195_01_0.033s.png
#             00195_00_0.033s.png
#             00194_10_0.04s.png
#             00194_08_0.04s.png
#             00194_09_0.04s.png
#             10045_01_0.04s.png
#             10045_00_0.04s.png
#             10045_00_0.1s.png
#             10040_07_0.1s.png
#             10040_09_0.1s.png
#             10040_08_0.1s.png
#             10040_05_0.1s.png
#             10040_06_0.1s.png
#             10040_03_0.1s.png
#             10040_04_0.1s.png
#             10040_02_0.1s.png
#             10035_10_0.1s.png
#             10040_01_0.04s.png
#             10040_01_0.1s.png
#             10040_00_0.04s.png
#             10032_00_0.1s.png
#             10030_09_0.1s.png
#             10030_07_0.1s.png
#             10030_08_0.1s.png
#             10030_06_0.1s.png
#             10030_01_0.1s.png
#             10030_03_0.1s.png
#             10030_05_0.1s.png
#             10030_04_0.1s.png
#             10030_02_0.1s.png
#             10030_01_0.04s.png
#             10030_00_0.1s.png
#             10022_09_0.1s.png
#             10022_07_0.1s.png
#             10022_06_0.1s.png
#             10030_00_0.04s.png
#             10022_08_0.1s.png
#             10022_05_0.1s.png
#             10022_04_0.1s.png
#             10022_03_0.1s.png
#             10022_01_0.04s.png
#             10022_00_0.04s.png
#             10016_09_0.1s.png
#             10016_04_0.1s.png
#             10016_05_0.1s.png
#             10016_03_0.1s.png
#             10011_09_0.1s.png
#             10016_01_0.1s.png
#             10016_00_0.1s.png
#             10016_00_0.04s.png
#             10011_03_0.1s.png
#             10011_01_0.1s.png
#             10011_02_0.1s.png
#             10006_06_0.1s.png
#             10006_03_0.1s.png
#             10006_00_0.04s.png
#             10006_01_0.04s.png
#             10006_02_0.1s.png
#             10006_00_0.1s.png
#             10006_01_0.1s.png
#             10003_08_0.1s.png
#             10003_09_0.1s.png
#             10003_02_0.1s.png
#             10003_06_0.1s.png
#             10003_04_0.1s.png
#             10003_07_0.1s.png
#             10003_03_0.1s.png
#             10003_05_0.1s.png
#             10003_03_0.04s.png
#             10003_02_0.04s.png
#             00232_09_0.04s.png
#             10003_00_0.1s.png
#             10003_01_0.1s.png
#             10003_00_0.04s.png
#             00232_08_0.04s.png
#             00232_07_0.04s.png
#             00232_06_0.04s.png
#             00232_03_0.04s.png
#             00232_01_0.04s.png
#             00230_09_0.04s.png
#             00231_00_0.1s.png
#             00230_02_0.04s.png
#             00225_06_0.04s.png
#             00225_07_0.04s.png
#             00230_00_0.033s.png
#             00225_08_0.04s.png
#             00225_04_0.04s.png
#             00225_05_0.04s.png
#             00225_01_0.033s.png
#             00225_01_0.1s.png
#             00225_03_0.04s.png
#             00225_01_0.04s.png
#             00225_02_0.04s.png
#             00225_00_0.033s.png
#             00225_00_0.1s.png
#             00225_00_0.04s.png
#             00224_08_0.04s.png
#             00224_09_0.04s.png
#             00224_06_0.04s.png
#             00224_07_0.04s.png
#             00224_05_0.04s.png
#             00224_01_0.04s.png
#             00224_01_0.1s.png
#             00224_04_0.04s.png
#             00224_03_0.04s.png
#             00224_02_0.04s.png
#             00223_09_0.04s.png
#             00224_01_0.033s.png
#             00224_00_0.1s.png
#             00224_00_0.033s.png
#             00224_00_0.04s.png
#             00223_08_0.04s.png
#             00223_07_0.04s.png
#             00223_06_0.04s.png
#             00223_02_0.04s.png
#             00223_05_0.04s.png
#             00223_01_0.1s.png
#             00222_07_0.04s.png
#             00222_04_0.04s.png
#             00220_08_0.04s.png
#             00220_07_0.04s.png
#             00220_04_0.04s.png
#             00220_05_0.04s.png
#             00220_06_0.04s.png
#             00220_03_0.04s.png
#             00220_00_0.1s.png
#             00220_02_0.04s.png
#             00220_01_0.04s.png
#             00220_01_0.1s.png
#             10093_06_0.1s.png
#             10093_04_0.1s.png
#             10093_09_0.1s.png
#             10093_02_0.1s.png
#             10093_07_0.1s.png
#             10093_05_0.1s.png
#             10087_09_0.1s.png
#             10087_08_0.1s.png
#             10093_03_0.1s.png
#             10087_06_0.1s.png
#             10087_07_0.1s.png
#             10093_01_0.1s.png
# ...
#     simpleUNET_63.png
#     simpleUNET_64.png
#     simpleUNET_65.png
#     simpleUNET_66.png
#     simpleUNET_67.png
#     simpleUNET_68.png
#     simpleUNET_69.png
#     simpleUNET_70.png
#     simpleUNET_71.png
#     simpleUNET_72.png
#     simpleUNET_73.png
#     simpleUNET_74.png
#     simpleUNET_75.png
#     simpleUNET_76.png
#     simpleUNET_77.png
#     simpleUNET_78.png
#     simpleUNET_79.png
#     simpleUNET_80.png
#     simpleUNET_81.png
#     simpleUNET_82.png
#     simpleUNET_83.png
#     simpleUNET_84.png
#     simpleUNET_85.png
#     simpleUNET_86.png
#     simpleUNET_87.png
#     simpleUNET_88.png
#     simpleUNET_89.png
#     simpleUNET_90.png
#     simpleUNET_91.png
#     simpleUNET_92.png
#     simpleUNET_93.png
#     simpleUNET_94.png
#     simpleUNET_95.png
#     simpleUNET_96.png
#     simpleUNET_97.png
#     simpleUNET_98.png
#     simpleUNET_99.png
#     simpleUNET_100.png
#     simpleUNET_101.png
#     simpleUNET_102.png
#     simpleUNET_103.png
#     simpleUNET_104.png
#     simpleUNET_105.png
#     simpleUNET_106.png
#     simpleUNET_107.png
#     simpleUNET_108.png
#     simpleUNET_109.png
#     simpleUNET_110.png
#     simpleUNET_111.png
#     simpleUNET_112.png
#     simpleUNET_113.png
#     simpleUNET_114.png
#     simpleUNET_115.png
#     simpleUNET_116.png
#     simpleUNET_117.png
#     simpleUNET_118.png
#     simpleUNET_119.png
#     simpleUNET_120.png
#     simpleUNET_121.png
#     simpleUNET_122.png
#     simpleUNET_123.png
#     simpleUNET_124.png
#     simpleUNET_125.png
#     simpleUNET_126.png
#     simpleUNET_127.png
#     simpleUNET_128.png
#     simpleUNET_129.png
#     simpleUNET_130.png
#     simpleUNET_131.png
#     simpleUNET_132.png
#     simpleUNET_133.png
#     simpleUNET_134.png
#     simpleUNET_135.png
#     simpleUNET_136.png
#     simpleUNET_137.png
#     simpleUNET_138.png
#     simpleUNET_139.png
#     simpleUNET_140.png
#     simpleUNET_141.png
#     simpleUNET_142.png
#     simpleUNET_143.png
#     simpleUNET_144.png
#     simpleUNET_145.png
#     simpleUNET_146.png
#     simpleUNET_147.png
#     simpleUNET_148.png
#     simpleUNET_149.png
#     simpleUNET_150.png
#     simpleUNET_151.png
#     simpleUNET_152.png
#     simpleUNET_153.png
#     simpleUNET_154.png
#     simpleUNET_155.png
#     simpleUNET_156.png
#     simpleUNET_157.png
#     simpleUNET_158.png
#     simpleUNET_159.png
#     simpleUNET_160.png
#     simpleUNET_161.png
#     simpleUNET_162.png
#     simpleUNET_163.png
#     simpleUNET_164.png
#     simpleUNET_165.png
#     simpleUNET_166.png
#     simpleUNET_167.png
#     simpleUNET_168.png
#     simpleUNET_169.png
#     simpleUNET_170.png
#     simpleUNET_171.png
#     simpleUNET_172.png
#     simpleUNET_173.png
#     simpleUNET_174.png
#     simpleUNET_175.png
#     simpleUNET_176.png
#     simpleUNET_177.png
#     simpleUNET_178.png
#     simpleUNET_179.png
#     simpleUNET_180.png
#     simpleUNET_181.png
#     simpleUNET_182.png
#     simpleUNET_183.png
#     simpleUNET_184.png
#     simpleUNET_185.png
#     simpleUNET_186.png
#     simpleUNET_187.png
#     simpleUNET_188.png
#     simpleUNET_189.png
#     simpleUNET_190.png
#     simpleUNET_191.png
#     simpleUNET_192.png
#     simpleUNET_193.png
#     simpleUNET_194.png
#     simpleUNET_195.png
#     simpleUNET_196.png
#     simpleUNET_197.png
#     simpleUNET_198.png
#     simpleUNET_199.png
#     simpleUNET_200.png
#     simpleUNET_201.png
#     simpleUNET_202.png
#     simpleUNET_203.png
#     simpleUNET_204.png
#     simpleUNET_205.png
#     simpleUNET_206.png
#     simpleUNET_207.png
#     simpleUNET_208.png
#     simpleUNET_209.png
#     simpleUNET_210.png
#     simpleUNET_211.png
#     simpleUNET_212.png
#     simpleUNET_213.png
#     simpleUNET_214.png
#     simpleUNET_215.png
#     simpleUNET_216.png
#     simpleUNET_217.png
#     simpleUNET_218.png
#     simpleUNET_219.png
#     simpleUNET_220.png
#     simpleUNET_221.png
#     simpleUNET_222.png
#     simpleUNET_223.png
#     simpleUNET_224.png
#     simpleUNET_225.png
#     simpleUNET_226.png
#     simpleUNET_227.png
#     simpleUNET_228.png
#     simpleUNET_229.png
#     simpleUNET_230.png
#     simpleUNET_231.png
#     simpleUNET_232.png
#     simpleUNET_233.png
#     simpleUNET_234.png
#     simpleUNET_235.png
#     simpleUNET_236.png
#     simpleUNET_237.png
#     simpleUNET_238.png
#     simpleUNET_239.png
#     simpleUNET_240.png
#     simpleUNET_241.png
#     simpleUNET_242.png
#     simpleUNET_243.png
#     simpleUNET_244.png
#     simpleUNET_245.png
#     simpleUNET_246.png
#     simpleUNET_247.png
#     simpleUNET_248.png
#     simpleUNET_249.png
#     simpleUNET_250.png
#     simpleUNET_251.png
#     simpleUNET_252.png
#     simpleUNET_253.png
#     simpleUNET_254.png
#     simpleUNET_255.png
#     simpleUNET_256.png
#     simpleUNET_257.png
#     simpleUNET_258.png
#     simpleUNET_259.png
#     simpleUNET_260.png
#     simpleUNET_261.png
#     simpleUNET_262.png
#     simpleUNET_263.png
#     simpleUNET_264.png
#     simpleUNET_265.png
#     simpleUNET_266.png
#     simpleUNET_267.png
#     simpleUNET_268.png
#     simpleUNET_269.png
#     simpleUNET_270.png
#     simpleUNET_271.png
#     simpleUNET_272.png
#     simpleUNET_273.png
#     simpleUNET_274.png
#     simpleUNET_275.png
#     simpleUNET_276.png
#     simpleUNET_277.png
#     simpleUNET_278.png
#     simpleUNET_279.png
#     simpleUNET_280.png
#     simpleUNET_281.png
#     simpleUNET_282.png
#     simpleUNET_283.png
#     simpleUNET_284.png
#     simpleUNET_285.png
#     simpleUNET_286.png
#     simpleUNET_287.png
#     simpleUNET_288.png
#     simpleUNET_289.png
#     simpleUNET_290.png
#     simpleUNET_291.png
#     simpleUNET_292.png
#     simpleUNET_293.png
#     simpleUNET_294.png
#     simpleUNET_295.png
#     simpleUNET_296.png
#     simpleUNET_297.png
#     simpleUNET_298.png
#     simpleUNET_299.png
#     simpleUNET_300.png
#     simpleUNET_301.png
#     simpleUNET_302.png
#     simpleUNET_303.png
#     simpleUNET_304.png
#     simpleUNET_305.png
#     simpleUNET_306.png
#     simpleUNET_307.png
#     simpleUNET_308.png
#     simpleUNET_309.png
#     simpleUNET_310.png
#     simpleUNET_311.png
#     simpleUNET_312.png
#     simpleUNET_313.png
#     simpleUNET_314.png
#     simpleUNET_315.png
#     simpleUNET_316.png
#     simpleUNET_317.png
#     simpleUNET_318.png
#     simpleUNET_319.png
#     simpleUNET_320.png
#     simpleUNET_321.png
#     simpleUNET_322.png
#     simpleUNET_323.png
#     simpleUNET_324.png
#     simpleUNET_325.png
#     simpleUNET_326.png
#     simpleUNET_327.png
#     simpleUNET_328.png
#     simpleUNET_329.png
#     simpleUNET_330.png
#     simpleUNET_331.png
#     simpleUNET_332.png
#     simpleUNET_333.png
#     simpleUNET_334.png
#     simpleUNET_335.png
#     simpleUNET_336.png
#     simpleUNET_337.png
#     simpleUNET_338.png
#     simpleUNET_339.png
#     simpleUNET_340.png
#     simpleUNET_341.png
#     simpleUNET_342.png
#     simpleUNET_343.png
#     simpleUNET_344.png
#     simpleUNET_345.png
#     simpleUNET_346.png
#     simpleUNET_347.png
#     simpleUNET_348.png
#     simpleUNET_349.png
#     simpleUNET_350.png
#     simpleUNET_351.png
#     simpleUNET_352.png
#     simpleUNET_353.png
#     simpleUNET_354.png
#     simpleUNET_355.png
#     simpleUNET_356.png
#     simpleUNET_357.png
#     simpleUNET_358.png
#     simpleUNET_359.png
#     simpleUNET_360.png
#     simpleUNET_361.png
#     simpleUNET_362.png
#     simpleUNET_363.png
#     simpleUNET_364.png
#     simpleUNET_365.png
#     simpleUNET_366.png
#     simpleUNET_367.png
#     simpleUNET_368.png
#     simpleUNET_369.png
#     simpleUNET_370.png
#     simpleUNET_371.png
#     simpleUNET_372.png
#     simpleUNET_373.png
#     simpleUNET_374.png
#     simpleUNET_375.png
#     simpleUNET_376.png
#     simpleUNET_377.png
#     simpleUNET_378.png
#     simpleUNET_379.png
#     simpleUNET_380.png
#     simpleUNET_381.png
#     simpleUNET_382.png
#     simpleUNET_383.png
#     simpleUNET_384.png
#     simpleUNET_385.png
#     simpleUNET_386.png
#     simpleUNET_387.png
#     simpleUNET_388.png
#     simpleUNET_389.png
#     simpleUNET_390.png
#     simpleUNET_391.png
#     simpleUNET_392.png
#     simpleUNET_393.png
#     simpleUNET_394.png
#     simpleUNET_395.png
#     simpleUNET_396.png
#     simpleUNET_397.png
#     gan_1.png
#     gan_2.png
#     gan_3.png
#     gan_4.png
#     gan_5.png
#     gan_6.png
#     gan_7.png
#     gan_8.png
#     gan_9.png
#     gan_10.png
#     gan_11.png
#     gan_12.png
#     gan_13.png
#     gan_14.png
#     gan_15.png
#     gan_16.png
#     gan_17.png
#     gan_18.png
#     gan_19.png
#     gan_20.png
#     gan_21.png
#     gan_22.png
#     gan_23.png
#     gan_24.png
#     gan_25.png
#     gan_26.png
#     gan_27.png
#     gan_28.png
#     gan_29.png
#     gan_30.png
#     gan_31.png
#     gan_32.png
#     gan_33.png
#     gan_34.png
#     gan_35.png
#     gan_36.png
#     gan_37.png
#     gan_38.png
#     gan_39.png
#     gan_40.png
#     gan_41.png
#     gan_42.png
#     gan_43.png
#     gan_44.png
#     gan_45.png
#     gan_46.png
#     gan_47.png
#     gan_48.png
#     gan_49.png
#     gan_50.png
#     gan_51.png
#     gan_52.png
#     gan_53.png
#     gan_54.png
#     gan_55.png
#     gan_56.png
#     gan_57.png
#     gan_58.png
#     gan_59.png
#     gan_60.png
#     gan_61.png
#     gan_62.png
#     gan_63.png
#     gan_64.png
#     gan_65.png
#     gan_66.png
#     gan_67.png
#     gan_68.png
#     gan_69.png
#     gan_70.png
#     gan_71.png
#     gan_72.png
#     gan_73.png
#     gan_74.png
#     gan_75.png
#     gan_76.png
#     gan_77.png
#     gan_78.png
#     gan_79.png
#     gan_80.png
#     gan_81.png
#     gan_82.png
#     gan_83.png
#     gan_84.png
#     gan_85.png
#     gan_86.png
#     gan_87.png
#     gan_88.png
#     gan_89.png
#     gan_90.png
#     gan_91.png
#     gan_92.png
#     gan_93.png
#     gan_94.png
#     gan_95.png
#     gan_96.png
#     gan_97.png
#     gan_98.png
#     gan_99.png
#     gan_100.png
#     gan_101.png
#     gan_102.png
#     gan_103.png
#     gan_104.png
#     gan_105.png
#     gan_106.png
#     gan_107.png
#     gan_108.png
#     gan_109.png
#     gan_110.png
#     gan_111.png
#     gan_112.png
#     gan_113.png
#     gan_114.png
#     gan_115.png
#     gan_116.png
#     gan_117.png
#     gan_118.png
#     gan_119.png
#     gan_120.png
#     gan_121.png
#     gan_122.png
#     gan_123.png
#     gan_124.png
#     gan_125.png
#     gan_126.png
#     gan_127.png
#     gan_128.png
#     gan_129.png
#     gan_130.png
#     gan_131.png
#     gan_132.png
#     gan_133.png
#     gan_134.png
#     gan_135.png
#     gan_136.png
#     gan_137.png
#     gan_138.png
#     gan_139.png
#     gan_140.png
#     gan_141.png
#     gan_142.png
#     gan_143.png
#     gan_144.png
#     gan_145.png
#     gan_146.png
#     gan_147.png
#     gan_148.png
#     gan_149.png
#     gan_150.png
#     gan_151.png
#     gan_152.png
#     gan_153.png
#     gan_154.png
#     gan_155.png
#     gan_156.png
#     gan_157.png
#     gan_158.png
#     gan_159.png
#     gan_160.png
#     gan_161.png
#     gan_162.png
#     gan_163.png
#     gan_164.png
#     gan_165.png
#     gan_166.png
#     gan_167.png
#     gan_168.png
#     gan_169.png
#     gan_170.png
#     gan_171.png
#     gan_172.png
#     gan_173.png
#     gan_174.png
#     gan_175.png
#     gan_176.png
#     gan_177.png
#     gan_178.png
#     gan_179.png
#     gan_180.png
#     gan_181.png
#     gan_182.png
#     gan_183.png
#     gan_184.png
#     gan_185.png
#     gan_186.png
#     gan_187.png
#     gan_188.png
#     gan_189.png
#     gan_190.png
#     gan_191.png
#     gan_192.png
#     gan_193.png
#     gan_194.png
#     gan_195.png
#     gan_196.png
#     gan_197.png
#     gan_198.png
#     gan_199.png
#     gan_200.png
#     gan_201.png
#     gan_202.png
#     gan_203.png
#     gan_204.png
#     gan_205.png
#     gan_206.png
#     gan_207.png
#     gan_208.png
#     gan_209.png
#     gan_210.png
#     gan_211.png
#     gan_212.png
#     gan_213.png
#     gan_214.png
#     gan_215.png
#     gan_216.png
#     gan_217.png
#     gan_218.png
#     gan_219.png
#     gan_220.png
#     gan_221.png
#     gan_222.png
#     gan_223.png
#     gan_224.png
#     gan_225.png
#     gan_226.png
#     gan_227.png
#     gan_228.png
#     gan_229.png
#     gan_230.png
#     gan_231.png
#     gan_232.png
#     gan_233.png
#     gan_234.png
#     gan_235.png
#     gan_236.png
#     gan_237.png
#     gan_238.png
#     gan_239.png
#     gan_240.png
#     gan_241.png
#     gan_242.png
#     gan_243.png
#     gan_244.png
#     gan_245.png
#     gan_246.png
#     gan_247.png
#     gan_248.png
#     gan_249.png
#     gan_250.png
#     gan_251.png
#     gan_252.png
#     gan_253.png
#     gan_254.png
#     gan_255.png
#     gan_256.png
#     gan_257.png
#     gan_258.png
#     gan_259.png
#     gan_260.png
#     gan_261.png
#     gan_262.png
#     gan_263.png
#     gan_264.png
#     gan_265.png
#     gan_266.png
#     gan_267.png
#     gan_268.png
#     gan_269.png
#     gan_270.png
#     gan_271.png
#     gan_272.png
#     gan_273.png
#     gan_274.png
#     gan_275.png
#     gan_276.png
#     gan_277.png
#     gan_278.png
#     gan_279.png
#     gan_280.png
#     gan_281.png
#     gan_282.png
#     gan_283.png
#     gan_284.png
#     gan_285.png
#     gan_286.png
#     gan_287.png
#     gan_288.png
#     gan_289.png
#     gan_290.png
#     gan_291.png
#     gan_292.png
#     gan_293.png
#     gan_294.png
#     gan_295.png
#     gan_296.png
#     gan_297.png
#     gan_298.png
#     gan_299.png
#     gan_300.png
#     gan_301.png
#     gan_302.png
#     gan_303.png
#     gan_304.png
#     gan_305.png
#     gan_306.png
#     gan_307.png
#     gan_308.png
#     gan_309.png
#     gan_310.png
#     gan_311.png
#     gan_312.png
#     gan_313.png
#     gan_314.png
#     gan_315.png
#     gan_316.png
#     gan_317.png
#     gan_318.png
#     gan_319.png
#     gan_320.png
#     gan_321.png
#     gan_322.png
#     gan_323.png
#     gan_324.png
#     gan_325.png
#     gan_326.png
#     gan_327.png
#     gan_328.png
#     gan_329.png
#     gan_330.png
#     gan_331.png
#     gan_332.png
#     gan_333.png
#     gan_334.png
#     gan_335.png
#     gan_336.png
#     gan_337.png
#     gan_338.png
#     gan_339.png
#     gan_340.png
#     gan_341.png
#     gan_342.png
#     gan_343.png
#     gan_344.png
#     gan_345.png
#     gan_346.png
#     gan_347.png
#     gan_348.png
#     gan_349.png
#     gan_350.png
#     gan_351.png
#     gan_352.png
#     gan_353.png
#     gan_354.png
#     gan_355.png
#     gan_356.png
#     gan_357.png
#     gan_358.png
#     gan_359.png
#     gan_360.png
#     gan_361.png
#     gan_362.png
#     gan_363.png
#     gan_364.png
#     gan_365.png
#     gan_366.png
#     gan_367.png
#     gan_368.png
#     gan_369.png
#     gan_370.png
#     gan_371.png
#     gan_372.png
#     gan_373.png
#     gan_374.png
#     gan_375.png
#     gan_376.png
#     gan_377.png
#     gan_378.png
#     gan_379.png
#     gan_380.png
#     gan_381.png
#     gan_382.png
#     gan_383.png
#     gan_384.png
#     gan_385.png
#     gan_386.png
#     gan_387.png
#     gan_388.png
#     gan_389.png
#     gan_390.png
#     gan_391.png
#     gan_392.png
#     gan_393.png
#     gan_394.png
#     gan_395.png
#     gan_396.png
#     gan_397.png
# models/
#     .gitkeep
#     ESmodel1.ckpt
#     ESmodel2.ckpt
#     ESmodel3.ckpt
#     ESmodel4.ckpt
#     ESmodel5.ckpt
#     ESmodel6.ckpt
#     ESmodel7.ckpt
#     ESmodel8.ckpt
#     ESmodel9.ckpt
#     ESmodel10.ckpt
#     ESmodel11.ckpt
#     ESmodel12.ckpt
#     ESmodel13.ckpt
#     ESmodel14.ckpt
#     ESmodel15.ckpt
#     ESmodel16.ckpt
#     ESmodel17.ckpt
#     ESmodel18.ckpt
#     ESmodel19.ckpt
#     ESmodel20.ckpt
#     ESmodel21.ckpt
#     ESmodel22.ckpt
#     ESmodel23.ckpt
#     ESmodel24.ckpt
#     ESmodel25.ckpt
#     ESmodel26.ckpt
#     ESmodel27.ckpt
#     ESmodel28.ckpt
#     ESmodel29.ckpt
#     ESmodel30.ckpt
#     ESmodel31.ckpt
#     ESmodel32.ckpt
#     ESmodel33.ckpt
#     ESmodel34.ckpt
#     ESmodel35.ckpt
#     ESmodel36.ckpt
#     ESmodel37.ckpt
#     ESmodel38.ckpt
#     ESmodel39.ckpt
#     ESmodel40.ckpt
#     ESmodel41.ckpt
#     ESmodel42.ckpt
#     ESmodel43.ckpt
#     ESmodel44.ckpt
#     ESmodel45.ckpt
#     ESmodel46.ckpt
#     ESmodel47.ckpt
#     ESmodel48.ckpt
#     ESmodel49.ckpt
#     ESmodel50.ckpt
#     ESmodel51.ckpt
#     ESmodel52.ckpt
#     ESmodel53.ckpt
#     ESmodel54.ckpt
#     ESmodel55.ckpt
#     ESmodel56.ckpt
#     ESmodel57.ckpt
#     ESmodel58.ckpt
#     ESmodel59.ckpt
#     ESmodel60.ckpt
#     ESmodel61.ckpt
#     ESmodel62.ckpt
#     ESmodel63.ckpt
#     ESmodel64.ckpt
#     ESmodel65.ckpt
#     ESmodel66.ckpt
#     ESmodel67.ckpt
#     bestESModel_simpleUNET.ckpt
#     bestESModel_gan.ckpt
#     ESmodel68.ckpt
#     ESmodel69.ckpt
#     ESmodel71.ckpt
#     ESmodel81.ckpt
#     ESmodel70.ckpt
#     ESmodel72.ckpt
#     ESmodel73.ckpt
#     ESmodel74.ckpt
#     ESmodel75.ckpt
#     ESmodel76.ckpt
#     ESmodel77.ckpt
#     ESmodel78.ckpt
#     ESmodel80.ckpt
#     ESmodel82.ckpt
#     ESmodel84.ckpt
#     ESmodel85.ckpt
#     ESmodel88.ckpt
# plots/
#     .gitkeep
#     _simpleUNETAvgValMSE_vs_Epochs.png
#     _simpleUNETAvgValSSIM_vs_Epochs.png
#     _simpleUNETLoss_vs_Iterations.png
#     ganAvgValMSE_vs_Epochs_Generator.png
#     ganAvgValSSIM_vs_Epochs_Generator.png
#     ganLoss_vs_Iterations_Generator.png
#     ganLoss_vs_Iterations_Discriminator.png
# __pycache__/
#     models_pytorch.cpython-36.pyc
#     datasetLoader_pytorch.cpython-36.pyc
#     gan_models.cpython-36.pyc

# %% [markdown]
# # Code

# %%
import os
import torch
import torch.nn as nn
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import transforms
# from torchvision.transforms.transforms import ToPILImage as trans
from torch.autograd import Variable
import torch.nn.functional as F
from skimage.measure import compare_ssim

# from gan_models import *
from datasetLoader_pytorch import SeeingIntTheDarkDataset

trans = transforms.ToPILImage()

# %%
n = 1234
np.random.seed(n)
torch.cuda.manual_seed_all(n)
torch.manual_seed(n)

# %%
def weights_init(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight.data, mean=0.0, std=1e-3)
        m.bias.data.fill_(0.0)
        
    if isinstance(m, nn.Conv2d):
        nn.init.xavier_normal_(m.weight.data) 
        m.bias.data.fill_(0.0)

def update_lr(optimizer, lr):
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
#sitd_dataset = SeeingIntTheDarkDataset(path+'dataset/Sony/short_temp_down/', path+'dataset/Sony/long_temp_down/', transforms.ToTensor())
sitd_dataset = SeeingIntTheDarkDataset(path+'dataset/Sony/short_down/', path+'dataset/Sony/long_down/', transforms.ToTensor())
print('Input Image Size:')
print(sitd_dataset[0][0].size())
# Out:
# Input Image Size:
# torch.Size([3, 128, 192])

# %%
#--------------------------------
# Device configuration
#--------------------------------
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if device == 'cuda':
    torch.cuda.set_device(1)

print('Using device: %s'%device)
# Out:
# Using device: cuda

# %%
#### final params
num_training= 2100
num_validation = 200
num_test = 397

num_epochs = 100
learning_rate = 1e-4
learning_rate_decay = 0.9
reg = 0.001
batch_size = 10

# ### dev params
#num_training= 20
#num_validation = 7
#num_test = 7

# %%
mask = list(range(num_training))
train_dataset = torch.utils.data.Subset(sitd_dataset, mask)

mask = list(range(num_training, num_training + num_validation))
val_dataset = torch.utils.data.Subset(sitd_dataset, mask)

mask = list(range(num_training + num_validation, num_training + num_validation + num_test))
test_dataset = torch.utils.data.Subset(sitd_dataset, mask)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

val_loader = torch.utils.data.DataLoader(dataset=val_dataset,
                                           batch_size=batch_size,
                                           shuffle=False)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)

# %%
import os
import torch
import torch.nn as nn
from skimage import io
import numpy as np
from torch.autograd import Variable
import torch.nn.functional as F

##################################################################################################
## Unet Instance norm model
class double_conv_in(nn.Module):

    def __init__(self, in_ch, out_ch):
        super(double_conv_in, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.InstanceNorm2d(out_ch),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.InstanceNorm2d(out_ch),
            nn.LeakyReLU(inplace=True)
        )

    def forward(self, x):
        x = self.conv(x)
        return x


class down_in(nn.Module):

    def __init__(self, in_ch, out_ch):
        super(down_in, self).__init__()
        self.mpconv = nn.Sequential(
            nn.MaxPool2d(2),
            double_conv_in(in_ch, out_ch)
        )

    def forward(self, x):
        x = self.mpconv(x)
        return x

class up_in(nn.Module):

    def __init__(self, in_ch, out_ch, bilinear=True):
        super(up_in, self).__init__()

        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        else:
            self.up = nn.ConvTranspose2d(in_ch//2, in_ch//2, 2, stride=2)

        self.conv = double_conv_in(in_ch, out_ch)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        
        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, (diffX // 2, diffX - diffX//2,
                        diffY // 2, diffY - diffY//2))
        
        # for padding issues, see 
        # https://github.com/HaiyongJiang/U-Net-Pytorch-Unstructured-Buggy/commit/0e854509c2cea854e247a9c615f175f76fbb2e3a
        # https://github.com/xiaopeng-liao/Pytorch-UNet/commit/8ebac70e633bac59fc22bb5195e513d5832fb3bd

        x = torch.cat([x2, x1], dim=1)
        x = self.conv(x)
        return x

class GaussianNoise(nn.Module):
    """Gaussian noise regularizer.

    Args:
        sigma (float, optional): relative standard deviation used to generate the
            noise. Relative means that it will be multiplied by the magnitude of
            the value your are adding the noise to. This means that sigma can be
            the same regardless of the scale of the vector.
        is_relative_detach (bool, optional): whether to detach the variable before
            computing the scale of the noise. If `False` then the scale of the noise
            won't be seen as a constant but something to optimize: this will bias the
            network to generate vectors with smaller values.
    """

    def __init__(self, sigma=1, is_relative_detach=True):
        super().__init__()
        self.sigma = sigma
        #self.is_relative_detach = is_relative_detach
        #self.noise = torch.tensor(0).to(device)

    def forward(self, x):
        if self.training and self.sigma != 0:
            #x = x.detach() if self.is_relative_detach else x
            #scale = self.sigma * x.detach() if self.is_relative_detach else self.sigma * x
            sampled_noise = torch.rand(x.size()).to(device) * self.sigma
            #sampled_noise = self.noise.repeat(*x.size()).normal_() * scale
            x = x + sampled_noise
        return x 

class unet_in_generator(nn.Module):

    def __init__(self):
        super(unet_in_generator,self).__init__()
        
        # self.train = train

        # https://github.com/alishdipani/U-net-Pytorch/blob/master/train_Unet.py
        self.inc = double_conv_in(3, 64)
        self.down1 = down_in(64, 128)
        self.down2 = down_in(128, 256)
        self.down3 = down_in(256, 512)
        self.down4 = down_in(512, 512)
        self.noise = GaussianNoise()
        self.up1 = up_in(1024, 256)
        self.up2 = up_in(512, 128)
        self.up3 = up_in(256, 64)
        self.up4 = up_in(128, 64)
        self.out1 = nn.Conv2d(64, 3, 3, padding=1)
        #self.out2 = DepthToSpace(2)

    def forward(self,x):
        
        #print('#################################')
        #print(x.size())
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        #print('########################')
        #print(x5.size())
        #print(z.size())
        
        x5_modified = self.noise(x5)
        
        # if self.train == True:
        #     x5 += torch.rand(x5.size())

        x = self.up1(x5_modified, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        x = self.out1(x)
        #x = self.out2(x)
        #print(x.size())

        return x
##################################################################################################

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        def discriminator_block(in_filters, out_filters, bn=True):
            block = [nn.Conv2d(in_filters, out_filters, 3, 1, 1), nn.MaxPool2d(2,2), nn.LeakyReLU(0.2, inplace=True), nn.Dropout2d(0.25)]
            if bn:
                block.append(nn.BatchNorm2d(out_filters, 0.8))
            return block

        self.model = nn.Sequential(
            *discriminator_block(3, 16, bn=False),
            *discriminator_block(16, 32),
            *discriminator_block(32, 64),
            *discriminator_block(64, 128)
        )

        self.adv_layer = nn.Sequential(nn.Linear(12288 , 1), nn.Sigmoid())

    def forward(self, img):
        out = self.model(img)
        #print(img.size())
        out = out.view(out.shape[0], -1)
        #print('Here',out.size())
        validity = self.adv_layer(out)

        return validity

# %%
def trainAndTestModel(name):

    generator = unet_in_generator()
    discriminator = Discriminator()

    generator.to(device)
    discriminator.to(device)

    generator.apply(weights_init)
    discriminator.apply(weights_init)

    # Loss and optimizer
    criterion = nn.BCELoss()
    optimizer_G = torch.optim.Adam(generator.parameters(), lr=learning_rate, weight_decay=reg)
    optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=learning_rate, weight_decay=reg)

    # Train the model
    lr = learning_rate
    GLoss = []                           #to save all the model losses
    DLoss = []
    valMSE = []
    valSSIM = []
    total_step = len(train_loader)

    for epoch in range(num_epochs):
        generator.train()
        for i, (in_images, exp_images) in enumerate(train_loader):
          
            # Move tensors to the configured device
            in_images = in_images.type(torch.FloatTensor).to(device)
            exp_images = exp_images.type(torch.FloatTensor).to(device)

            # Adversarial ground truths
            valid = torch.ones([batch_size, 1]).to(device) # Discriminator Label to real
            fake = torch.zeros([batch_size, 1]).to(device) # Discriminator Lab
            # valid = Variable(torch.Tensor(1).fill_(1.0), requires_grad=False)
            # fake = Variable(torch.Tensor(1).fill_(0.0), requires_grad=False)

            ###############################
            # Generator update
            # Forward pass
            #z = Variable(torch.rand((batch_size, 512, 8, 12))).to(device)

            gen_images = generator(in_images)
            g_loss = criterion(discriminator(gen_images), valid)
            GLoss.append(g_loss)               #save the loss so we can get accuracies later

            # Backward and optimize
            optimizer_G.zero_grad()
            g_loss.backward()
            optimizer_G.step()

            ###############################
            # Discriminator update
            # Measure discriminator's ability to classify real from generated samples
            real_loss = criterion(discriminator(exp_images), valid)
            fake_loss = criterion(discriminator(gen_images.detach()), fake)
            
            d_loss = (real_loss + fake_loss) / 2
            DLoss.append(d_loss)

            optimizer_D.zero_grad()
            d_loss.backward()
            optimizer_D.step()

            if (i+1) % 20 == 0:
                print ('Epoch [{}/{}], Step [{}/{}], Gen_Loss: {:.6f}, Disc_Loss: {:.6f}'
                    .format(epoch+1, num_epochs, i+1, total_step, g_loss.item(), d_loss.item() ) )
        
        # Code to update the lr
        lr *= learning_rate_decay
        update_lr(optimizer_D, lr)
        update_lr(optimizer_G, lr)

        with torch.no_grad():
            generator.eval()
            
            overallSSIM = 0
            MSE = 0
            for in_images, exp_images in val_loader:
                in_images = in_images.to(device)
                exp_images = exp_images.to(device)
                #z = torch.zeros((batch_size, 512, 8, 12)).to(device)
                outputs = generator(in_images)

                MSE += torch.sum((outputs - exp_images) ** 2)
                #outputs = outputs.cpu()
                outputs_np = outputs.permute(0, 2, 3, 1).cpu().numpy() 
                exp_images_np = exp_images.permute(0,2,3,1).cpu().numpy()

                SSIM = 0
                for i in range(len(outputs_np)):
                    SSIM += compare_ssim(exp_images_np[i], outputs_np[i], multichannel=True)

                overallSSIM += SSIM

            
            total = len(val_dataset)
            valSSIM.append(overallSSIM/total)

            current_MSE = MSE/total
            valMSE.append(current_MSE)
            if current_MSE <= np.amin(valMSE):
                torch.save(generator.state_dict(),path+'models/ESmodel'+str(epoch+1)+'.ckpt')

            print('Avg Validation MSE on all the {} Val images is: {} '.format(total, current_MSE))
            print('Avg Validation SSIM on all the {} Val images is: {} '.format(total, overallSSIM/total))

    # Training loss and Val MSE curves
    plt.plot(valMSE)
    title='AvgValMSE_vs_Epochs_Generator'
    plt.ylabel('Avg Validation MSE')
    plt.xlabel('Epochs')
    plt.title(title)
    plt.savefig(path+'plots/'+name+title+'.png')
    plt.close()

    plt.plot(valSSIM)
    title='AvgValSSIM_vs_Epochs_Generator'
    plt.ylabel('Avg Validation SSIM')
    plt.xlabel('Epochs')
    plt.title(title)
    plt.savefig(path+'plots/'+name+title+'.png')
    plt.close()

    plt.plot(GLoss)
    title='Loss_vs_Iterations_Generator'
    plt.ylabel('Generator Loss')
    plt.xlabel('Iterations')
    plt.title(title)
    plt.savefig(path+'plots/'+name+title+'.png')
    plt.close()

    plt.plot(DLoss)
    title='Loss_vs_Iterations_Discriminator'
    plt.ylabel('Discriminator Loss')
    plt.xlabel('Iterations')
    plt.title(title)
    plt.savefig(path+'plots/'+name+title+'.png')
    plt.close()

    print('Testing ..............................')

    # last_model = model
    best_id = np.argmin(valMSE)
    bestESmodel = generator

    bestESmodel.load_state_dict(torch.load(path+'models/ESmodel'+str(best_id+1)+'.ckpt'))
    bestESmodel = bestESmodel.to(device)


    # last_model.eval()
    bestESmodel.eval()
    
        
    with torch.no_grad():

        overallSSIM = 0
        MSE = 0
        count = 0 
        for in_images, exp_images in test_loader:
            
            in_images = in_images.to(device)
            exp_images = exp_images.to(device)
            
            #z = torch.zeros((batch_size, 512, 8, 12)).to(device)
            outputs = bestESmodel(in_images)

            MSE += torch.sum((outputs - exp_images) ** 2)

            # Visualize the output of the best model against ground truth
            in_images_py = in_images.cpu()
            outputs_py = outputs.cpu()
            exp_images_py = exp_images.cpu()
            
            reqd_size = int(in_images.size()[0])

            for i in range(reqd_size):

                img = in_images_py[i].numpy()
                nonZero = np.count_nonzero(img)
                count += 1 
                f, axarr = plt.subplots(1,3)
                title='Input ('+str(round((nonZero*100)/(192*128*3), 2))+'% Non Zero) vs Model Output vs Ground truth'
                plt.suptitle(title)
                axarr[0].imshow(trans(in_images_py[i]))
                axarr[1].imshow(trans(outputs_py[i]))
                axarr[2].imshow(trans(exp_images_py[i]))
                
                plt.savefig(path+'images/'+name+'_%d.png'%(count))
                plt.close()

                if count % 10 == 0:
                    print('Saving image_%d.png'%(count))

            outputs_np = outputs.permute(0, 2, 3, 1).cpu().numpy()
            exp_images_np = exp_images.permute(0, 2, 3, 1).cpu().numpy()

            SSIM = 0
            for i in range(len(outputs_np)):
                SSIM += compare_ssim(exp_images_np[i], outputs_np[i], multichannel=True)

            overallSSIM += SSIM

        total = len(test_dataset)
        print('Avg Test MSE of the best ES network on all the {} test images: {} '.format(total, MSE/total))
        print('Avg Test SSIM of the best ES network on all the {} test images: {} '.format(total, overallSSIM/total))
        print("Best Epoch with lowest Avg Validation MSE: ", best_id+1)

    torch.save(bestESmodel.state_dict(), path+'models/bestESModel_'+name+'.ckpt')

# %%
#torch.autograd.set_detect_anomaly(True)

# %%
###############################################################################################################################################
# parameters to select different models ==> Just change here. 
name = 'gan'

trainAndTestModel(name)
# Out:
# Epoch [1/100], Step [20/210], Gen_Loss: 0.678379, Disc_Loss: 0.703273
# Epoch [1/100], Step [40/210], Gen_Loss: 0.676484, Disc_Loss: 0.699998
# Epoch [1/100], Step [60/210], Gen_Loss: 0.675715, Disc_Loss: 0.707708
# Epoch [1/100], Step [80/210], Gen_Loss: 0.686452, Disc_Loss: 0.699599
# Epoch [1/100], Step [100/210], Gen_Loss: 0.718528, Disc_Loss: 0.688152
# Epoch [1/100], Step [120/210], Gen_Loss: 0.680706, Disc_Loss: 0.703149
# Epoch [1/100], Step [140/210], Gen_Loss: 0.695816, Disc_Loss: 0.697905
# Epoch [1/100], Step [160/210], Gen_Loss: 0.695505, Disc_Loss: 0.696847
# Epoch [1/100], Step [180/210], Gen_Loss: 0.694649, Disc_Loss: 0.695249
# Epoch [1/100], Step [200/210], Gen_Loss: 0.681597, Disc_Loss: 0.702460
# Avg Validation MSE on all the 200 Val images is: 808361.5625
# Avg Validation SSIM on all the 200 Val images is: 0.0024606532456702486
# Epoch [2/100], Step [20/210], Gen_Loss: 0.703597, Disc_Loss: 0.684565
# Epoch [2/100], Step [40/210], Gen_Loss: 0.683450, Disc_Loss: 0.702126
# Epoch [2/100], Step [60/210], Gen_Loss: 0.696561, Disc_Loss: 0.696807
# Epoch [2/100], Step [80/210], Gen_Loss: 0.710855, Disc_Loss: 0.683479
# Epoch [2/100], Step [100/210], Gen_Loss: 0.690361, Disc_Loss: 0.695917
# Epoch [2/100], Step [120/210], Gen_Loss: 0.698078, Disc_Loss: 0.691611
# Epoch [2/100], Step [140/210], Gen_Loss: 0.709940, Disc_Loss: 0.692734
# Epoch [2/100], Step [160/210], Gen_Loss: 0.697291, Disc_Loss: 0.689478
# Epoch [2/100], Step [180/210], Gen_Loss: 0.689970, Disc_Loss: 0.694922
# Epoch [2/100], Step [200/210], Gen_Loss: 0.701193, Disc_Loss: 0.690055
# Avg Validation MSE on all the 200 Val images is: 445530.71875
# Avg Validation SSIM on all the 200 Val images is: -0.04259708189960179
# Epoch [3/100], Step [20/210], Gen_Loss: 0.698848, Disc_Loss: 0.687851
# Epoch [3/100], Step [40/210], Gen_Loss: 0.690017, Disc_Loss: 0.691182
# Epoch [3/100], Step [60/210], Gen_Loss: 0.697675, Disc_Loss: 0.689001
# Epoch [3/100], Step [80/210], Gen_Loss: 0.690146, Disc_Loss: 0.691051
# Epoch [3/100], Step [100/210], Gen_Loss: 0.691154, Disc_Loss: 0.691139
# Epoch [3/100], Step [120/210], Gen_Loss: 0.690008, Disc_Loss: 0.693384
# Epoch [3/100], Step [140/210], Gen_Loss: 0.690685, Disc_Loss: 0.694332
# Epoch [3/100], Step [160/210], Gen_Loss: 0.694771, Disc_Loss: 0.693815
# Epoch [3/100], Step [180/210], Gen_Loss: 0.692652, Disc_Loss: 0.692860
# Epoch [3/100], Step [200/210], Gen_Loss: 0.691274, Disc_Loss: 0.693780
# Avg Validation MSE on all the 200 Val images is: 3365.708251953125
# Avg Validation SSIM on all the 200 Val images is: 0.35728201300055706
# Epoch [4/100], Step [20/210], Gen_Loss: 0.693227, Disc_Loss: 0.693538
# Epoch [4/100], Step [40/210], Gen_Loss: 0.693219, Disc_Loss: 0.693308
# Epoch [4/100], Step [60/210], Gen_Loss: 0.693092, Disc_Loss: 0.694341
# Epoch [4/100], Step [80/210], Gen_Loss: 0.692360, Disc_Loss: 0.694034
# Epoch [4/100], Step [100/210], Gen_Loss: 0.693845, Disc_Loss: 0.693721
# Epoch [4/100], Step [120/210], Gen_Loss: 0.694652, Disc_Loss: 0.693766
# Epoch [4/100], Step [140/210], Gen_Loss: 0.693018, Disc_Loss: 0.694053
# Epoch [4/100], Step [160/210], Gen_Loss: 0.692996, Disc_Loss: 0.692867
# Epoch [4/100], Step [180/210], Gen_Loss: 0.694231, Disc_Loss: 0.692811
# Epoch [4/100], Step [200/210], Gen_Loss: 0.692707, Disc_Loss: 0.693192
# Avg Validation MSE on all the 200 Val images is: 5061.38720703125
# Avg Validation SSIM on all the 200 Val images is: 0.2613801477045951
# Epoch [5/100], Step [20/210], Gen_Loss: 0.692244, Disc_Loss: 0.693543
# Epoch [5/100], Step [40/210], Gen_Loss: 0.693781, Disc_Loss: 0.693592
# Epoch [5/100], Step [60/210], Gen_Loss: 0.693483, Disc_Loss: 0.693641
# Epoch [5/100], Step [80/210], Gen_Loss: 0.692485, Disc_Loss: 0.692349
# Epoch [5/100], Step [100/210], Gen_Loss: 0.692775, Disc_Loss: 0.693779
# Epoch [5/100], Step [120/210], Gen_Loss: 0.693742, Disc_Loss: 0.693689
# Epoch [5/100], Step [140/210], Gen_Loss: 0.693897, Disc_Loss: 0.693050
# Epoch [5/100], Step [160/210], Gen_Loss: 0.693043, Disc_Loss: 0.693597
# Epoch [5/100], Step [180/210], Gen_Loss: 0.693705, Disc_Loss: 0.693611
# Epoch [5/100], Step [200/210], Gen_Loss: 0.693598, Disc_Loss: 0.693282

# %%
import torch
torch.rand(1)
